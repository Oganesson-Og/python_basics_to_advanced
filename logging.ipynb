# %% [markdown]
# # Generic logging

# %%
import logging

logging.debug('This is a debug message')
logging.info('This is an information message')
logging.warning('This is a warning message')
logging.critical('This is a critical message')
logging.error('This is a error message')
# Out:
# WARNING:root:This is a warning message
# CRITICAL:root:This is a critical message
# ERROR:root:This is a error message

# %% [markdown]
# # To ensure that logging includes other levels

# %%
import logging
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(name)s- %(levelname)s- %(message)s',
                    datefmt='%d/%m/%Y %H:%M:%S')

logging.debug('This is a debug message')
logging.info('This is an information message')
logging.warning('This is a warning message')
logging.critical('This is a critical message')
logging.error('This is a error message')
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 869, in format
#     return fmt.format(record)
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 611, in format
#     s = self.formatMessage(record)
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 580, in formatMessage
#     return self._style.format(record)
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 422, in format
#     return self._fmt % record.__dict__
# ValueError: unsupported format character '%' (0x25) at index 11
# Call stack:
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
# ...

# %% [markdown]
# # It is encouraged to create your own logger using the method below. Avoid root logger as we used above

# %%
import logging
logger = logging.getLogger(__name__)
logger.info('This logger will appear with the name of the file saved')
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 869, in format
#     return fmt.format(record)
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 611, in format
#     s = self.formatMessage(record)
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 580, in formatMessage
#     return self._style.format(record)
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 422, in format
#     return self._fmt % record.__dict__
# ValueError: unsupported format character '%' (0x25) at index 11
# Call stack:
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
# ...

# %%
import logging

# Create and configure a logger
logging.basicConfig(filename= 'C:\\Users\\Admin\\Videos\\Python\\oga_logging.log')

# %%
logger = logging.getLogger()

logger.info('My first logged message')
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 1025, in emit
#     msg = self.format(record)
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 869, in format
#     return fmt.format(record)
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 611, in format
#     s = self.formatMessage(record)
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 580, in formatMessage
#     return self._style.format(record)
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 422, in format
#     return self._fmt % record.__dict__
# ValueError: unsupported format character '%' (0x25) at index 11
# Call stack:
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
# ...
